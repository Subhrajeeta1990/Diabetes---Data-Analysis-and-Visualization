# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df1=pd.read_csv("/kaggle/input/diabetes-health-indicators-dataset/diabetes_binary_5050split_health_indicators_BRFSS2015.csv")
df2=pd.read_csv("/kaggle/input/diabetes-health-indicators-dataset/diabetes_binary_health_indicators_BRFSS2015.csv")
df3=pd.read_csv("/kaggle/input/diabetes-health-indicators-dataset/diabetes_012_health_indicators_BRFSS2015.csv")

# %%
df1.head(2)

# %%
df2.head(3)

# %%
df3.tail(2)

# %%
print(df1.shape)
print(df2.shape)
print(df3.shape)

# %%
print(df1.columns)
print("***********")
print(df2.columns)
print("***********")
print(df3.columns)

# %%
df3["Diabetes_012"].unique()

# %%
df1["Diabetes_binary"].unique()

# %%
df2.info()

# %%
df=pd.concat([df1,df2])

# %%
df

# %%
df.shape

# %%
df.info()

# %%
df.isnull().sum()

# %%
df.describe()

# %%
df.describe().T

# %%
df["Diabetes_binary"].value_counts()

# %%
df.groupby(["Diabetes_binary"])["HighBP"].value_counts()

# %%
df.groupby(["Diabetes_binary"])["HighBP"].count()

# %%
(df.groupby(["Diabetes_binary"])["HighBP"].value_counts()/df.groupby(["Diabetes_binary"])["HighBP"].count())*100

# %%
df.groupby(["Diabetes_binary"])["HighChol"].value_counts()

# %%
df.groupby(["Diabetes_binary"])["HighChol"].count()

# %%
(df.groupby(["Diabetes_binary"])["HighChol"].value_counts()/df.groupby(["Diabetes_binary"])["HighChol"].count())*100

# %%
import seaborn as sns

# %%
sns.barplot(x="Diabetes_binary",y="BMI",data=df)

# %%
df[df["BMI"]>=40]["Diabetes_binary"].value_counts()

# %%
df["Smoker"].value_counts()

# %%
df.groupby(["Smoker"])["Diabetes_binary"].value_counts()

# %%
df.groupby(["Smoker","Diabetes_binary"])["HighBP"].value_counts()

# %%
df.groupby(["Smoker","Diabetes_binary"])["HighBP"].count()

# %%
(df.groupby(["Smoker","Diabetes_binary"])["HighBP"].value_counts()/df.groupby(["Smoker","Diabetes_binary"])["HighBP"].count())*100

# %%
df.iloc[50:101,2:7]

# %%
df[(df["Diabetes_binary"]==1) & (df["HeartDiseaseorAttack"]==1)]["Diabetes_binary"].value_counts()

# %%
a=df[(df["Diabetes_binary"]==1) & (df["Income"]==1)][["HvyAlcoholConsump","PhysActivity","Sex"]].value_counts()
a

# %%
b=df[(df["Diabetes_binary"]==1) & (df["Income"]==1)][["HvyAlcoholConsump","PhysActivity","Sex"]].count()
b

# %%
df.groupby(["Diabetes_binary","PhysActivity"])["Sex"].agg(["min","max","mean","median","std","var"])

# %%
np.where(df["Age"]>8)

# %%
sns.relplot(x="Age", y ="Diabetes_binary", data = df,hue = "Sex",col = "Smoker");

# %%
sns.relplot(x="Age", y ="Diabetes_binary", data = df,col="Sex");

# %%
df.reset_index(inplace=True)

# %%
df.drop(columns="index",inplace =True)

# %%
df

# %%
sns.pairplot(df)

# %%
sns.jointplot(x="Diabetes_binary",y="PhysHlth",data=df)

# %%
(df.groupby(["Diabetes_binary"])["Sex"].value_counts()/df.groupby(["Diabetes_binary"])["Sex"].count())*100

# %%
(df.groupby("Age")["Diabetes_binary"].value_counts()/df.groupby("Age")["Diabetes_binary"].count())*100

# %%
(df.groupby(["Education","PhysActivity"])["Diabetes_binary"].value_counts()/df.groupby(["Education","PhysActivity"])["Diabetes_binary"].count())*100

# %%
(df.groupby(["Income","PhysActivity"])["Diabetes_binary"].value_counts()/df.groupby(["Income","PhysActivity"])["Diabetes_binary"].count())*100

# %%
(df.groupby(["HeartDiseaseorAttack","PhysHlth"])["Diabetes_binary"].value_counts()/df.groupby(["HeartDiseaseorAttack","PhysHlth"])["Diabetes_binary"].count())*100

# %%
(df.groupby(["HeartDiseaseorAttack"])["Diabetes_binary"].value_counts()/df.groupby(["HeartDiseaseorAttack"])["Diabetes_binary"].count())*100

# %%
(df.groupby(["NoDocbcCost","Income"])["Diabetes_binary"].value_counts()/df.groupby(["NoDocbcCost","Income"])["Diabetes_binary"].count())*100

# %%
df.columns

# %%
df[df["Diabetes_binary"]==1]

# %%
df[df["Diabetes_binary"]==1][['GenHlth','MentHlth', 'PhysHlth','Age', 'Education','Income','BMI']].agg(["min","max","mean"]).T

# %%
sns.catplot(x="Age",y="BMI",data=df,hue="Diabetes_binary",kind="bar");

# %%
sns.catplot(x="Income",y="PhysHlth",data=df,hue="Diabetes_binary",col="PhysActivity",kind="bar");

# %%
sns.relplot(x="Age",y="Income",data=df,hue="Diabetes_binary",style="NoDocbcCost",kind="line",ci=True);

# %%
sns.scatterplot(x="GenHlth",y="BMI",hue="Diabetes_binary",data=df);

# %%
sns.violinplot(x="HvyAlcoholConsump",y="Smoker",hue="Diabetes_binary",data=df);
plt.legend(loc= 'best');

# %%
sns.lineplot(x="Fruits",y="Veggies",hue="Diabetes_binary",data=df);

# %%
import matplotlib.pyplot as plt

# %%
sns.lineplot(x="Age",y="Education",hue="Diabetes_binary",style="Income",data=df,ci=True);
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0);

# %%
sns.relplot(x="MentHlth",y="PhysHlth",hue="Diabetes_binary",data=df,kind="line");

# %%
sns.countplot(x="AnyHealthcare",data=df,hue="Diabetes_binary");
